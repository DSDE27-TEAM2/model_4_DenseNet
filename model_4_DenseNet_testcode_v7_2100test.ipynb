# %%
import tensorflow as tf
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt

from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.client import device_lib

from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# 이미지 데이터 경로 설정
data_dir = 'fer2013_train' # 폴더 경로 설정 (사이즈 작은 이미지 / 2,100장 테스트)
input_shape = (224, 224)
batch_size = 32
num_classes = 7  # 클래스 개수에 맞게 설정

# 훈련셋, 검증셋, 테스트셋으로 데이터 나누기

train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    validation_split=0.3,  # 훈련셋 70%, 검증셋 30%
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)

# 훈련셋, 검증셋, 테스트셋으로 데이터 나누기
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255,
    validation_split=0.2,  # 훈련셋 80%, 검증셋 20%
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)

# 훈련셋 제너레이터 생성
train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=input_shape,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # 'training' subset은 훈련셋으로 사용
)

# 검증셋 제너레이터 생성
valid_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=input_shape,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # 'validation' subset은 검증셋으로 사용
)

# 테스트셋 제너레이터 생성
test_dir = 'fer2013_test'
test_generator = train_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape,
    batch_size=batch_size,
    class_mode='categorical',
    subset=None 
)


# 모델 체크포인트 콜백 정의
checkpoint_path = 'DenseNet_testcode_V7_2100test_01.h5'
checkpoint = ModelCheckpoint(
    checkpoint_path, 
    monitor='val_accuracy',  # 저장할 모델을 선택할 지표 설정 (여기서는 검증 정확도)
    save_best_only=True,     # 최상의 성능을 보이는 경우에만 저장
    mode='max',              # 지표의 최대값을 찾음
    verbose=1                # 저장할 때 메시지 출력
)
# Out:
# Found 22968 images belonging to 1 classes.
# Found 5741 images belonging to 1 classes.
# Found 7178 images belonging to 1 classes.

# %%
def DenseNet(x):
    # input = 224 x 224 x 3
    k = 32  # Grow Rate
    compression = 0.2   # 밀집 블록 내에서 출력 채널 수를 줄임 (모델의 파라미터 수와 연산량을 줄이면서도 효과적인 특성 추출)


    # 1. Convolution
    # 입력 이미지에 7x7 크기의 필터를 사용하는 Convolution 레이어를 적용
    x = layers.Conv2D(k * 2, (7, 7), strides=2, padding='same', input_shape=(224, 224, 3))(x)    # 112x112x64
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    # 2. Pooling
    # 이미지 내의 중요한 특성을 보존하면서 크기를 줄임
    x = layers.MaxPool2D((3, 3), 2, padding='same')(x)  # 56x56x64


    # 5. Dense Block (2)
    for i in range(3) :
        x_l = layers.Conv2D(k * 4, (1, 1), strides=1, padding='same')(x)
        x_l = layers.BatchNormalization()(x_l)
        x_l = layers.Activation('relu')(x_l)

        x_l = layers.Conv2D(k, (3, 3), strides=1, padding='same')(x_l)
        x_l = layers.BatchNormalization()(x_l)
        x_l = layers.Activation('relu')(x_l)

        x = layers.Concatenate()([x, x_l])


    # 6. Transition Layer (2)
    current_shape = int(x.shape[-1])
    x = layers.Conv2D(int(current_shape * compression), (1, 1), strides=1, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.AveragePooling2D((2, 2), strides=2, padding='same')(x)   # 14x14


    # 7. Dense Block (3)
    for i in range(24) :
        x_l = layers.Conv2D(k * 4, (1, 1), strides=1, padding='same')(x)
        x_l = layers.BatchNormalization()(x_l)
        x_l = layers.Activation('relu')(x_l)

        x_l = layers.Conv2D(k, (3, 3), strides=1, padding='same')(x_l)
        x_l = layers.BatchNormalization()(x_l)
        x_l = layers.Activation('relu')(x_l)

        x = layers.Concatenate()([x, x_l])

    # 8. Transition Layer (3)
    current_shape = int(x.shape[-1])
    x = layers.Conv2D(int(current_shape * compression), (1, 1), strides=1, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.AveragePooling2D((2, 2), strides=2, padding='same')(x)   # 7x7


    # 9. Dense Block (4)
    for i in range(6) :
        x_l = layers.Conv2D(k * 4, (1, 1), strides=1, padding='same')(x)
        x_l = layers.BatchNormalization()(x_l)
        x_l = layers.Activation('relu')(x_l)

        x_l = layers.Conv2D(k, (3, 3), strides=1, padding='same')(x_l)
        x_l = layers.BatchNormalization()(x_l)
        x_l = layers.Activation('relu')(x_l)

        x = layers.Concatenate()([x, x_l])

    # 10. Classification Layer
    x = layers.GlobalAveragePooling2D()(x)
    # classes = 7 (softmax)
    x = layers.Dense(7, activation='softmax')(x)

    return x

# %%
# 모델 생성
input_layer = layers.Input(shape=(*input_shape, 3), dtype='float32', name='input')
output_layer = DenseNet(input_layer)
model = tf.keras.Model(inputs=input_layer, outputs=output_layer)

# %%
# 클래스 개수 설정
num_classes = 7

# 모델 컴파일
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.1),
              loss='categorical_crossentropy',  # 다중 클래스 분류용 함수
              metrics=['acc'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 112, 112, 64)         9472      ['input[0][0]']
#
#  batch_normalization (Batch  (None, 112, 112, 64)         256       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 112, 112, 64)         0         ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 64)           0         ['activation[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 56, 56, 128)          8320      ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 56, 56, 128)          512       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 56, 56, 128)          0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 32)           36896     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 56, 56, 32)           128       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 56, 56, 32)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  concatenate (Concatenate)   (None, 56, 56, 96)           0         ['max_pooling2d[0][0]',
#                                                                      'activation_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 128)          12416     ['concatenate[0][0]']
#
#  batch_normalization_3 (Bat  (None, 56, 56, 128)          512       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 56, 56, 128)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 32)           36896     ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 56, 56, 32)           128       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 56, 56, 32)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  concatenate_1 (Concatenate  (None, 56, 56, 128)          0         ['concatenate[0][0]',
#  )                                                                   'activation_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 128)          16512     ['concatenate_1[0][0]']
#
#  batch_normalization_5 (Bat  (None, 56, 56, 128)          512       ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 56, 56, 128)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 32)           36896     ['activation_5[0][0]']
#
#  batch_normalization_6 (Bat  (None, 56, 56, 32)           128       ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 56, 56, 32)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  concatenate_2 (Concatenate  (None, 56, 56, 160)          0         ['concatenate_1[0][0]',
#  )                                                                   'activation_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 56, 56, 32)           5152      ['concatenate_2[0][0]']
#
#  batch_normalization_7 (Bat  (None, 56, 56, 32)           128       ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 56, 56, 32)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  average_pooling2d (Average  (None, 28, 28, 32)           0         ['activation_7[0][0]']
#  Pooling2D)
#  conv2d_8 (Conv2D)           (None, 28, 28, 128)          4224      ['average_pooling2d[0][0]']
#
#  batch_normalization_8 (Bat  (None, 28, 28, 128)          512       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 28, 28, 128)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 32)           36896     ['activation_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 28, 28, 32)           128       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 28, 28, 32)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  concatenate_3 (Concatenate  (None, 28, 28, 64)           0         ['average_pooling2d[0][0]',
#  )                                                                   'activation_9[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 128)          8320      ['concatenate_3[0][0]']
#
#  batch_normalization_10 (Ba  (None, 28, 28, 128)          512       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 28, 28, 32)           128       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  concatenate_4 (Concatenate  (None, 28, 28, 96)           0         ['concatenate_3[0][0]',
#  )                                                                   'activation_11[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 28, 28, 128)          12416     ['concatenate_4[0][0]']
#
#  batch_normalization_12 (Ba  (None, 28, 28, 128)          512       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 28, 28, 32)           128       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  concatenate_5 (Concatenate  (None, 28, 28, 128)          0         ['concatenate_4[0][0]',
#  )                                                                   'activation_13[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 28, 28, 128)          16512     ['concatenate_5[0][0]']
#
#  batch_normalization_14 (Ba  (None, 28, 28, 128)          512       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 28, 28, 32)           128       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  concatenate_6 (Concatenate  (None, 28, 28, 160)          0         ['concatenate_5[0][0]',
#  )                                                                   'activation_15[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 28, 28, 128)          20608     ['concatenate_6[0][0]']
#
#  batch_normalization_16 (Ba  (None, 28, 28, 128)          512       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_16[0][0]']
#
#  batch_normalization_17 (Ba  (None, 28, 28, 32)           128       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  concatenate_7 (Concatenate  (None, 28, 28, 192)          0         ['concatenate_6[0][0]',
#  )                                                                   'activation_17[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 28, 28, 128)          24704     ['concatenate_7[0][0]']
#
#  batch_normalization_18 (Ba  (None, 28, 28, 128)          512       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_18[0][0]']
#
#  batch_normalization_19 (Ba  (None, 28, 28, 32)           128       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  concatenate_8 (Concatenate  (None, 28, 28, 224)          0         ['concatenate_7[0][0]',
#  )                                                                   'activation_19[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 28, 28, 128)          28800     ['concatenate_8[0][0]']
#
#  batch_normalization_20 (Ba  (None, 28, 28, 128)          512       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_20[0][0]']
#
#  batch_normalization_21 (Ba  (None, 28, 28, 32)           128       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  concatenate_9 (Concatenate  (None, 28, 28, 256)          0         ['concatenate_8[0][0]',
#  )                                                                   'activation_21[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 28, 28, 128)          32896     ['concatenate_9[0][0]']
#
#  batch_normalization_22 (Ba  (None, 28, 28, 128)          512       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_22[0][0]']
#
#  batch_normalization_23 (Ba  (None, 28, 28, 32)           128       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  concatenate_10 (Concatenat  (None, 28, 28, 288)          0         ['concatenate_9[0][0]',
#  e)                                                                  'activation_23[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 28, 28, 128)          36992     ['concatenate_10[0][0]']
#
#  batch_normalization_24 (Ba  (None, 28, 28, 128)          512       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_24[0][0]']
#
#  batch_normalization_25 (Ba  (None, 28, 28, 32)           128       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  concatenate_11 (Concatenat  (None, 28, 28, 320)          0         ['concatenate_10[0][0]',
#  e)                                                                  'activation_25[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 28, 28, 128)          41088     ['concatenate_11[0][0]']
#
#  batch_normalization_26 (Ba  (None, 28, 28, 128)          512       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_26[0][0]']
#
#  batch_normalization_27 (Ba  (None, 28, 28, 32)           128       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  concatenate_12 (Concatenat  (None, 28, 28, 352)          0         ['concatenate_11[0][0]',
#  e)                                                                  'activation_27[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 28, 28, 128)          45184     ['concatenate_12[0][0]']
#
#  batch_normalization_28 (Ba  (None, 28, 28, 128)          512       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_28[0][0]']
#
#  batch_normalization_29 (Ba  (None, 28, 28, 32)           128       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  concatenate_13 (Concatenat  (None, 28, 28, 384)          0         ['concatenate_12[0][0]',
#  e)                                                                  'activation_29[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 28, 28, 128)          49280     ['concatenate_13[0][0]']
#
#  batch_normalization_30 (Ba  (None, 28, 28, 128)          512       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_30[0][0]']
#
#  batch_normalization_31 (Ba  (None, 28, 28, 32)           128       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  concatenate_14 (Concatenat  (None, 28, 28, 416)          0         ['concatenate_13[0][0]',
#  e)                                                                  'activation_31[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 28, 28, 128)          53376     ['concatenate_14[0][0]']
#
#  batch_normalization_32 (Ba  (None, 28, 28, 128)          512       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_32[0][0]']
#
#  batch_normalization_33 (Ba  (None, 28, 28, 32)           128       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  concatenate_15 (Concatenat  (None, 28, 28, 448)          0         ['concatenate_14[0][0]',
#  e)                                                                  'activation_33[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 28, 28, 128)          57472     ['concatenate_15[0][0]']
#  batch_normalization_34 (Ba  (None, 28, 28, 128)          512       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_34[0][0]']
#
#  batch_normalization_35 (Ba  (None, 28, 28, 32)           128       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  concatenate_16 (Concatenat  (None, 28, 28, 480)          0         ['concatenate_15[0][0]',
#  e)                                                                  'activation_35[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 28, 28, 128)          61568     ['concatenate_16[0][0]']
#
#  batch_normalization_36 (Ba  (None, 28, 28, 128)          512       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_36[0][0]']
#
#  batch_normalization_37 (Ba  (None, 28, 28, 32)           128       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  concatenate_17 (Concatenat  (None, 28, 28, 512)          0         ['concatenate_16[0][0]',
#  e)                                                                  'activation_37[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 28, 28, 128)          65664     ['concatenate_17[0][0]']
#
#  batch_normalization_38 (Ba  (None, 28, 28, 128)          512       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_39 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_38[0][0]']
#
#  batch_normalization_39 (Ba  (None, 28, 28, 32)           128       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  concatenate_18 (Concatenat  (None, 28, 28, 544)          0         ['concatenate_17[0][0]',
#  e)                                                                  'activation_39[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 28, 28, 128)          69760     ['concatenate_18[0][0]']
#
#  batch_normalization_40 (Ba  (None, 28, 28, 128)          512       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_40[0][0]']
#
#  batch_normalization_41 (Ba  (None, 28, 28, 32)           128       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  concatenate_19 (Concatenat  (None, 28, 28, 576)          0         ['concatenate_18[0][0]',
#  e)                                                                  'activation_41[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 28, 28, 128)          73856     ['concatenate_19[0][0]']
#
#  batch_normalization_42 (Ba  (None, 28, 28, 128)          512       ['conv2d_42[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_42[0][0]']
#
#  batch_normalization_43 (Ba  (None, 28, 28, 32)           128       ['conv2d_43[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  concatenate_20 (Concatenat  (None, 28, 28, 608)          0         ['concatenate_19[0][0]',
#  e)                                                                  'activation_43[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 28, 28, 128)          77952     ['concatenate_20[0][0]']
#
#  batch_normalization_44 (Ba  (None, 28, 28, 128)          512       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_44[0][0]']
#
#  batch_normalization_45 (Ba  (None, 28, 28, 32)           128       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  concatenate_21 (Concatenat  (None, 28, 28, 640)          0         ['concatenate_20[0][0]',
#  e)                                                                  'activation_45[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 28, 28, 128)          82048     ['concatenate_21[0][0]']
#
#  batch_normalization_46 (Ba  (None, 28, 28, 128)          512       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_46 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_47 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_46[0][0]']
#
#  batch_normalization_47 (Ba  (None, 28, 28, 32)           128       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_47 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  concatenate_22 (Concatenat  (None, 28, 28, 672)          0         ['concatenate_21[0][0]',
#  e)                                                                  'activation_47[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 28, 28, 128)          86144     ['concatenate_22[0][0]']
#
#  batch_normalization_48 (Ba  (None, 28, 28, 128)          512       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  activation_48 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_48[0][0]']
#
#  batch_normalization_49 (Ba  (None, 28, 28, 32)           128       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_49 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  concatenate_23 (Concatenat  (None, 28, 28, 704)          0         ['concatenate_22[0][0]',
#  e)                                                                  'activation_49[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 28, 28, 128)          90240     ['concatenate_23[0][0]']
#
#  batch_normalization_50 (Ba  (None, 28, 28, 128)          512       ['conv2d_50[0][0]']
#  tchNormalization)
#
# ...
#
#  batch_normalization_53 (Ba  (None, 28, 28, 32)           128       ['conv2d_53[0][0]']
#  tchNormalization)
#
#  activation_53 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  concatenate_25 (Concatenat  (None, 28, 28, 768)          0         ['concatenate_24[0][0]',
#  e)                                                                  'activation_53[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 28, 28, 128)          98432     ['concatenate_25[0][0]']
#
#  batch_normalization_54 (Ba  (None, 28, 28, 128)          512       ['conv2d_54[0][0]']
#  tchNormalization)
#
#  activation_54 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 28, 28, 32)           36896     ['activation_54[0][0]']
#
#  batch_normalization_55 (Ba  (None, 28, 28, 32)           128       ['conv2d_55[0][0]']
#  tchNormalization)
#
#  activation_55 (Activation)  (None, 28, 28, 32)           0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  concatenate_26 (Concatenat  (None, 28, 28, 800)          0         ['concatenate_25[0][0]',
#  e)                                                                  'activation_55[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 28, 28, 160)          128160    ['concatenate_26[0][0]']
#
#  batch_normalization_56 (Ba  (None, 28, 28, 160)          640       ['conv2d_56[0][0]']
#  tchNormalization)
#
#  activation_56 (Activation)  (None, 28, 28, 160)          0         ['batch_normalization_56[0][0]
#                                                                     ']
#
#  average_pooling2d_1 (Avera  (None, 14, 14, 160)          0         ['activation_56[0][0]']
#  gePooling2D)
#
#  conv2d_57 (Conv2D)          (None, 14, 14, 128)          20608     ['average_pooling2d_1[0][0]']
#
#  batch_normalization_57 (Ba  (None, 14, 14, 128)          512       ['conv2d_57[0][0]']
#  tchNormalization)
#
#  activation_57 (Activation)  (None, 14, 14, 128)          0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  conv2d_58 (Conv2D)          (None, 14, 14, 32)           36896     ['activation_57[0][0]']
#
#  batch_normalization_58 (Ba  (None, 14, 14, 32)           128       ['conv2d_58[0][0]']
#  tchNormalization)
#
#  activation_58 (Activation)  (None, 14, 14, 32)           0         ['batch_normalization_58[0][0]
#                                                                     ']
#
#  concatenate_27 (Concatenat  (None, 14, 14, 192)          0         ['average_pooling2d_1[0][0]',
#  e)                                                                  'activation_58[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 14, 14, 128)          24704     ['concatenate_27[0][0]']
#
#  batch_normalization_59 (Ba  (None, 14, 14, 128)          512       ['conv2d_59[0][0]']
#  tchNormalization)
#
#  activation_59 (Activation)  (None, 14, 14, 128)          0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  conv2d_60 (Conv2D)          (None, 14, 14, 32)           36896     ['activation_59[0][0]']
#
#  batch_normalization_60 (Ba  (None, 14, 14, 32)           128       ['conv2d_60[0][0]']
#  tchNormalization)
#
#  activation_60 (Activation)  (None, 14, 14, 32)           0         ['batch_normalization_60[0][0]
#                                                                     ']
#
#  concatenate_28 (Concatenat  (None, 14, 14, 224)          0         ['concatenate_27[0][0]',
#  e)                                                                  'activation_60[0][0]']
#
#  conv2d_61 (Conv2D)          (None, 14, 14, 128)          28800     ['concatenate_28[0][0]']
#
#  batch_normalization_61 (Ba  (None, 14, 14, 128)          512       ['conv2d_61[0][0]']
#  tchNormalization)
#
#  activation_61 (Activation)  (None, 14, 14, 128)          0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  conv2d_62 (Conv2D)          (None, 14, 14, 32)           36896     ['activation_61[0][0]']
#
#  batch_normalization_62 (Ba  (None, 14, 14, 32)           128       ['conv2d_62[0][0]']
#  tchNormalization)
#
#  activation_62 (Activation)  (None, 14, 14, 32)           0         ['batch_normalization_62[0][0]
#                                                                     ']
#
#  concatenate_29 (Concatenat  (None, 14, 14, 256)          0         ['concatenate_28[0][0]',
#  e)                                                                  'activation_62[0][0]']
#
#  conv2d_63 (Conv2D)          (None, 14, 14, 128)          32896     ['concatenate_29[0][0]']
#
#  batch_normalization_63 (Ba  (None, 14, 14, 128)          512       ['conv2d_63[0][0]']
#  tchNormalization)
#
#  activation_63 (Activation)  (None, 14, 14, 128)          0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  conv2d_64 (Conv2D)          (None, 14, 14, 32)           36896     ['activation_63[0][0]']
#
#  batch_normalization_64 (Ba  (None, 14, 14, 32)           128       ['conv2d_64[0][0]']
#  tchNormalization)
#
#  activation_64 (Activation)  (None, 14, 14, 32)           0         ['batch_normalization_64[0][0]
#                                                                     ']
#
#  concatenate_30 (Concatenat  (None, 14, 14, 288)          0         ['concatenate_29[0][0]',
#  e)                                                                  'activation_64[0][0]']
#
#  conv2d_65 (Conv2D)          (None, 14, 14, 128)          36992     ['concatenate_30[0][0]']
#
#  batch_normalization_65 (Ba  (None, 14, 14, 128)          512       ['conv2d_65[0][0]']
#  tchNormalization)
#
#  activation_65 (Activation)  (None, 14, 14, 128)          0         ['batch_normalization_65[0][0]
#                                                                     ']
#
#  conv2d_66 (Conv2D)          (None, 14, 14, 32)           36896     ['activation_65[0][0]']
#
#  batch_normalization_66 (Ba  (None, 14, 14, 32)           128       ['conv2d_66[0][0]']
#  tchNormalization)
#
#  activation_66 (Activation)  (None, 14, 14, 32)           0         ['batch_normalization_66[0][0]
#                                                                     ']
#
#  concatenate_31 (Concatenat  (None, 14, 14, 320)          0         ['concatenate_30[0][0]',
#  e)                                                                  'activation_66[0][0]']
#
#  conv2d_67 (Conv2D)          (None, 14, 14, 128)          41088     ['concatenate_31[0][0]']
#
#  batch_normalization_67 (Ba  (None, 14, 14, 128)          512       ['conv2d_67[0][0]']
#  tchNormalization)
#
#  activation_67 (Activation)  (None, 14, 14, 128)          0         ['batch_normalization_67[0][0]
#                                                                     ']
#
#  conv2d_68 (Conv2D)          (None, 14, 14, 32)           36896     ['activation_67[0][0]']
#
#  batch_normalization_68 (Ba  (None, 14, 14, 32)           128       ['conv2d_68[0][0]']
#  tchNormalization)
#
#  activation_68 (Activation)  (None, 14, 14, 32)           0         ['batch_normalization_68[0][0]
#                                                                     ']
#
#  concatenate_32 (Concatenat  (None, 14, 14, 352)          0         ['concatenate_31[0][0]',
#  e)                                                                  'activation_68[0][0]']
#  global_average_pooling2d (  (None, 352)                  0         ['concatenate_32[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 7)                    2471      ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 2839175 (10.83 MB)
# Trainable params: 2828103 (10.79 MB)
# Non-trainable params: 11072 (43.25 KB)
# __________________________________________________________________________________________________

# %%
# model = tf.keras.models.load_model(checkpoint_path) # checkpoint 모델 불러오기

# %%
# 모델 학습
epochs = 50
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=valid_generator,
    validation_steps=valid_generator.samples // batch_size
)

# 훈련 과정의 손실과 정확도 추출
train_loss = history.history['loss']
train_acc = history.history['accuracy']
val_loss = history.history['val_loss']
val_acc = history.history['val_accuracy']

# 테스트셋 평가
test_loss, test_accuracy = model.evaluate(
    test_generator,
    steps=test_generator.samples // batch_size
)

# 결과 출력
print("Training Loss:", train_loss)
print("Training Accuracy:", train_acc)
print("Validation Loss:", val_loss)
print("Validation Accuracy:", val_acc)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/50
# 400/718 [===============>..............] - ETA: 29:12 - loss: nan - acc: 0.6668

# %%
# 클래스 이름과 인덱스 매핑 출력
print(train_generator.class_indices)

# %%
# Accuracy 그래프
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# Loss 그래프
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
